# %%
#linked list
1)it is a linear ds made up of chain of nodes 
2)each node contain datafield and link or reference
3)it also contain 2 links one is prev linnk and other is next link in middle it conatin data

# %%
terms:

Node: elements of linked list

# %%
# Advantagees:
1)dynamic ds--that means while creating the linked list we dont need  set the limit
2)insertion and deletion is easy
3)you can use linked list to implement stack queue and graph
4)represents and manipulate the polynomial

# In real life:
web browser: it go to the previous and next page
music player: songs are linked
imagfe viewer: images are linked
treasure hunt

#disadvantages:
1)needs extra memory
2)random access is not possible

# %%
linked_list:
1)single linked lsit
2)doubly linked list
3)circular linked list

# %%
#single linked list
 each node contain datafield and only one link that refer to the next link
2) it only moves in the forward direction beacause it only contain the link to the next Node
3) backward direction is not easier

# %%
#operations
add
delete
traverse

# %%
add----to add the node we need to break the existing link and the add the new link
# begin:
1)create a node
2)change new_node next = head
head --> new_node 

# end:
1)create Node
2)go to last Node
3)ref lastnode = newnode

# inb/w:
1)create Node
2)go to node just before required position of newNode

# %%
# deletion:
# begin:we need to change the link to the secound node
# end: go to the secound last node and change it position of the to null
# inb/w: change the address of the ele before to the ele next

# %%
# traverasal:
start with head if the head is not  NULL access the info,go the next node access the info 
1

# %%
# implementation:
1)create node
2)create a linked_list

# %%
class node:
    def __init__(self, data):
        self.data = data
        self.ref = None
        
# node1 = node(10)

# print(node1)
class LinkedList:
    def __init__(self):
        self.head = None
        
    def print_LL(self):
        if self.head is None:
            print("linked list is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data)
                n = n.ref
LL1 = LinkedList()
LL1.print_LL()
# Out:
# linked list is empty!

# %%
# # adding: at begining
# 1)create a node
# 2)new-node.ref = head
# 3)head = new-node

class node:
    def __init__(self, data):
        self.data = data
        self.ref = None
        
# node1 = node(10)

# print(node1)
class LinkedList:
    def __init__(self):
        self.head = None
        
    def print_LL(self):
        if self.head is None:
            print("linked list is empty!")
        else:
            n = self.head
            while n is not None:
                print(n.data, "--->", end = " ")
                n = n.ref
    def add_begin(self, data):
        new_node = node(data)
        new_node.ref = self.head
        self.head = new_node
        
    def add_end(self, data):
        new_node = node(data)
        if self.head is None:
            self.head = new_node
            
        else:
            n = self.head
            while n.ref is not None:
                n = n.ref
                
            n.ref = new_node
            
    def add_after(self, data, x):
        n = self.head
        while n is not None:
            if x==n.data:
                break
            n = n.ref
            
        if n is None:
            print("NONE")
        else:
            new_node = node(data)
            new_node.ref = self.head.ref
            self.head.ref = new_node
    
    def add_before(self, data, x):
        n = self.head
        
        if n is None:
            print("Linked List is empty")
            return      
        if n.data==x:
            new_node = node(data)
            new_node.ref = self.head
            self.head = new_node
            return
        while n.ref is not None:
            if n.ref.data==x:
                break
            n = n.ref
            
        if n.ref is None:
            print("None is empty")
            
        else:
            new_node = node(data)
            new_node.ref = n.ref
            n.ref = new_node
            
    def insert_empty(self, data):
        if self.head is None:
            new_node = node(data)
            self.head = new_node    
        else:
            print("Linked List is not empty")    

    def remove_begin(self):
        if self.head is None:
            print("Linked is empty")
            return      
        if self.head is not None:
            self.head = self.head.ref 
            return 
    
    def remove_end(self):
        n = self.head
        if self.head is None:
            print("Linked is empty")
        else:
            while n.ref.ref is not None:
                n = n.ref
            n.ref = None   
            
    def remove_any(self,x):
        n = self.head
        if self.head is None:
            print("Linked is empty")
            return
        if x==self.head.data:
            self.head = self.head.ref 
            return
        while n.ref is not None:
            if x==n.ref.data:
                break
            n = n.ref
        if n.ref is None:
            print("NOd is not present!")
        else:
            n.ref = n.ref.ref    
            
            
            
        
        
        
          
            
    
            
            
            
        
            
            
            
LL1 = LinkedList()
# LL1.add_begin(10)
# LL1.add_end(100)
# LL1.add_end(1000)
# LL1.add_after(1)

# LL1.add_begin(20)
# LL1.add_end(100)
# LL1.add_end(20)
# LL1.add_begin(10)
# LL1.add_after(200,100)
# LL1.add_before(142,200)
# LL1.insert_empty(123456)
LL1.add_begin(1)
LL1.add_begin(12)
LL1.add_begin(14)
# LL1.remove_end()
# LL1.remove_any(12)
LL1.add_after(7,12)
LL1.add_before(8,12)

LL1.print_LL()
# Out:
# 14 ---> 7 ---> 8 ---> 12 ---> 1 --->
